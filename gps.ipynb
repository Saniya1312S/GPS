# %%
import random
import folium
from geopy.distance import geodesic
import datetime

# Define classes and functions
class TollArea:
    def __init__(self, name, entry_point, exit_point, speed_limit, toll_rate):
        self.name = name
        self.entry_point = entry_point
        self.exit_point = exit_point
        self.speed_limit = speed_limit
        self.toll_rate = toll_rate

    def calculate_toll(self, distance, time_of_day):
        # Dynamic pricing: increase toll rates during peak hours (e.g., 7-10 AM, 5-8 PM)
        peak_hours = [(7, 10), (17, 20)]
        for start, end in peak_hours:
            if start <= time_of_day.hour < end:
                return distance * self.toll_rate * 1.5
        return distance * self.toll_rate

class Vehicle:
    def __init__(self, id, start_location):
        self.id = id
        self.current_location = start_location
        self.total_distance = 0
        self.total_toll = 0

    def move(self, toll_area):
        distance = geodesic(toll_area.entry_point, toll_area.exit_point).km
        speed = random.uniform(toll_area.speed_limit - 10, toll_area.speed_limit + 20)  # Simulated speed
        self.current_location = toll_area.exit_point
        self.total_distance += distance
        now = datetime.datetime.now()
        toll_charge = toll_area.calculate_toll(distance, now)
        self.total_toll += toll_charge

        speed_warning = ""
        if speed > toll_area.speed_limit:
            speed_warning = " (Speed Limit Exceeded!)"
        
        return distance, toll_charge, speed, speed_warning

def simulate_traffic(toll_areas, vehicles, steps):
    for step in range(steps):
        for vehicle in vehicles:
            toll_area = random.choice(toll_areas)
            distance, toll_charge, speed, speed_warning = vehicle.move(toll_area)
            print(f"Vehicle {vehicle.id} entered {toll_area.name}. Distance: {distance:.2f} km, Toll Charge: ₹{toll_charge:.2f}, Speed: {speed:.2f} km/h{speed_warning}, Total Distance: {vehicle.total_distance:.2f} km, Total Toll: ₹{vehicle.total_toll:.2f}")

# Define a map area (example coordinates for a city area in Maharashtra)
map_center = [19.0760, 72.8777]  # Mumbai coordinates
map_zoom_start = 10

# Create a folium map
m = folium.Map(location=map_center, zoom_start=map_zoom_start)

# Define toll areas with entry and exit points, speed limits, and toll rates
toll_areas = [
    TollArea("Bhopal Toll", (23.2599, 77.4126), (23.2945, 77.3943), 60, 5.0),
    TollArea("Indore Toll", (22.7196, 75.8577), (22.7556, 75.8852), 50, 4.0),
    TollArea("Nagpur Toll", (21.1458, 79.0882), (21.2514, 79.1575), 70, 6.0),
    TollArea("Bhandara Toll", (21.1690, 79.6880), (21.1774, 79.6819), 55, 3.5),
    TollArea("Raipur Toll", (21.2514, 81.6296), (21.2920, 81.6369), 65, 4.5)
]


# Add toll areas to the map
for area in toll_areas:
    folium.Marker(location=area.entry_point, popup=f"Entry: {area.name}").add_to(m)
    folium.Marker(location=area.exit_point, popup=f"Exit: {area.name}").add_to(m)
    folium.PolyLine(locations=[area.entry_point, area.exit_point], color='blue').add_to(m)

# Initialize vehicles
vehicles = [Vehicle(id, map_center) for id in range(1, 6)]

# Run the simulation for 10 steps
simulate_traffic(toll_areas, vehicles, 10)

# Add vehicle positions and total charges to the map
for vehicle in vehicles:
    folium.Marker(location=vehicle.current_location, popup=f"Vehicle {vehicle.id}, Total Toll: ₹{vehicle.total_toll:.2f}").add_to(m)

# Save the map to an HTML file
m.save("toll_areas_map2.html")
# Out:
# Vehicle 1 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 78.88 km/h (Speed Limit Exceeded!), Total Distance: 4.26 km, Total Toll: ₹21.32
# Vehicle 2 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 68.89 km/h, Total Distance: 13.73 km, Total Toll: ₹82.37
# Vehicle 3 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 65.85 km/h (Speed Limit Exceeded!), Total Distance: 4.89 km, Total Toll: ₹19.54
# Vehicle 4 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 71.53 km/h (Speed Limit Exceeded!), Total Distance: 13.73 km, Total Toll: ₹82.37
# Vehicle 5 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 57.88 km/h, Total Distance: 4.56 km, Total Toll: ₹20.51
# Vehicle 1 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 60.54 km/h, Total Distance: 8.82 km, Total Toll: ₹41.84
# Vehicle 2 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 63.42 km/h (Speed Limit Exceeded!), Total Distance: 18.61 km, Total Toll: ₹101.92
# Vehicle 3 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 50.07 km/h, Total Distance: 9.15 km, Total Toll: ₹40.87
# Vehicle 4 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 66.86 km/h (Speed Limit Exceeded!), Total Distance: 14.85 km, Total Toll: ₹86.31
# Vehicle 5 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 60.56 km/h (Speed Limit Exceeded!), Total Distance: 9.44 km, Total Toll: ₹40.06
# Vehicle 1 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 68.10 km/h (Speed Limit Exceeded!), Total Distance: 13.38 km, Total Toll: ₹62.35
# Vehicle 2 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 41.38 km/h, Total Distance: 23.50 km, Total Toll: ₹121.46
# Vehicle 3 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 61.34 km/h, Total Distance: 13.71 km, Total Toll: ₹61.38
# Vehicle 4 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 67.42 km/h (Speed Limit Exceeded!), Total Distance: 19.12 km, Total Toll: ₹107.64
# Vehicle 5 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 66.64 km/h (Speed Limit Exceeded!), Total Distance: 14.00 km, Total Toll: ₹60.57
# Vehicle 1 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 71.04 km/h (Speed Limit Exceeded!), Total Distance: 27.11 km, Total Toll: ₹144.72
# Vehicle 2 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 78.41 km/h (Speed Limit Exceeded!), Total Distance: 27.77 km, Total Toll: ₹142.78
# Vehicle 3 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 57.43 km/h, Total Distance: 17.97 km, Total Toll: ₹82.71
# Vehicle 4 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 80.14 km/h (Speed Limit Exceeded!), Total Distance: 23.68 km, Total Toll: ₹128.15
# Vehicle 5 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 73.46 km/h (Speed Limit Exceeded!), Total Distance: 15.13 km, Total Toll: ₹64.51
# Vehicle 1 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 70.82 km/h (Speed Limit Exceeded!), Total Distance: 40.84 km, Total Toll: ₹227.10
# Vehicle 2 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 62.20 km/h (Speed Limit Exceeded!), Total Distance: 28.89 km, Total Toll: ₹146.72
# Vehicle 3 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 61.42 km/h, Total Distance: 22.53 km, Total Toll: ₹103.22
# Vehicle 4 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 63.25 km/h (Speed Limit Exceeded!), Total Distance: 24.80 km, Total Toll: ₹132.09
# Vehicle 5 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 66.74 km/h, Total Distance: 28.86 km, Total Toll: ₹146.88
# Vehicle 1 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 68.82 km/h (Speed Limit Exceeded!), Total Distance: 45.73 km, Total Toll: ₹246.64
# Vehicle 2 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 68.06 km/h, Total Distance: 42.62 km, Total Toll: ₹229.10
# Vehicle 3 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 44.89 km/h, Total Distance: 27.42 km, Total Toll: ₹122.76
# Vehicle 4 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 69.61 km/h (Speed Limit Exceeded!), Total Distance: 25.93 km, Total Toll: ₹136.03
# Vehicle 5 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 59.71 km/h (Speed Limit Exceeded!), Total Distance: 29.98 km, Total Toll: ₹150.82
# Vehicle 1 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 67.63 km/h (Speed Limit Exceeded!), Total Distance: 49.99 km, Total Toll: ₹267.97
# Vehicle 2 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 87.87 km/h (Speed Limit Exceeded!), Total Distance: 56.35 km, Total Toll: ₹311.47
# Vehicle 3 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 70.83 km/h (Speed Limit Exceeded!), Total Distance: 28.54 km, Total Toll: ₹126.70
# Vehicle 4 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 56.77 km/h, Total Distance: 30.49 km, Total Toll: ₹156.54
# Vehicle 5 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 65.42 km/h (Speed Limit Exceeded!), Total Distance: 34.54 km, Total Toll: ₹171.34
# Vehicle 1 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 59.49 km/h, Total Distance: 54.26 km, Total Toll: ₹289.29
# Vehicle 2 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 77.54 km/h (Speed Limit Exceeded!), Total Distance: 70.08 km, Total Toll: ₹393.84
# Vehicle 3 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 53.35 km/h, Total Distance: 32.81 km, Total Toll: ₹148.03
# Vehicle 4 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 57.70 km/h, Total Distance: 35.05 km, Total Toll: ₹177.05
# Vehicle 5 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 52.77 km/h (Speed Limit Exceeded!), Total Distance: 39.43 km, Total Toll: ₹190.88
# Vehicle 1 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 58.04 km/h (Speed Limit Exceeded!), Total Distance: 55.38 km, Total Toll: ₹293.23
# Vehicle 2 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 60.63 km/h (Speed Limit Exceeded!), Total Distance: 74.96 km, Total Toll: ₹413.38
# Vehicle 3 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 71.17 km/h (Speed Limit Exceeded!), Total Distance: 33.93 km, Total Toll: ₹151.97
# Vehicle 4 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 84.76 km/h (Speed Limit Exceeded!), Total Distance: 48.77 km, Total Toll: ₹259.43
# Vehicle 5 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 60.97 km/h, Total Distance: 43.99 km, Total Toll: ₹211.39
# Vehicle 1 entered Bhandara Toll. Distance: 1.13 km, Toll Charge: ₹3.94, Speed: 55.40 km/h (Speed Limit Exceeded!), Total Distance: 56.51 km, Total Toll: ₹297.17
# Vehicle 2 entered Nagpur Toll. Distance: 13.73 km, Toll Charge: ₹82.37, Speed: 86.72 km/h (Speed Limit Exceeded!), Total Distance: 88.69 km, Total Toll: ₹495.76
# Vehicle 3 entered Indore Toll. Distance: 4.89 km, Toll Charge: ₹19.54, Speed: 47.63 km/h, Total Distance: 38.82 km, Total Toll: ₹171.51
# Vehicle 4 entered Raipur Toll. Distance: 4.56 km, Toll Charge: ₹20.51, Speed: 84.04 km/h (Speed Limit Exceeded!), Total Distance: 53.33 km, Total Toll: ₹279.94
# Vehicle 5 entered Bhopal Toll. Distance: 4.26 km, Toll Charge: ₹21.32, Speed: 52.91 km/h, Total Distance: 48.25 km, Total Toll: ₹232.72
